# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Acquisition
# ## Live demo

# %%
dataset = pd.read_csv('data/synthetic_health_lifestyle_dataset.csv')

# %%
dataset
# Out:
#         ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker   Exercise_Freq  \
# 0        1   56   Other      177.6       37.3  11.8    Yes             NaN
# 1        2   69   Other      169.3       70.7  24.7     No  1-2 times/week
# 2        3   46  Female      159.1       69.0  27.3     No           Daily
# 3        4   32    Male      170.6       76.4  26.3     No  3-5 times/week
# 4        5   60    Male      158.4       60.4  24.1     No  3-5 times/week
# ...    ...  ...     ...        ...        ...   ...    ...             ...
# 7495  7496   55   Other      168.3       52.4  18.5    Yes  1-2 times/week
# 7496  7497   24    Male      179.1       58.8  18.3     No  3-5 times/week
# 7497  7498   61   Other      160.2       80.0  31.2     No  3-5 times/week
# 7498  7499   40  Female      172.6       66.1  22.2     No  1-2 times/week
# 7499  7500   58   Other      163.8       59.3  22.1     No           Daily
#
# ...

# %%
dataset.replace('None', np.nan, inplace=True)

# %%
missing_data = dataset.isnull().sum().reset_index()

# %%
missing_data.columns = ['Column', 'Missing values count']

# %%
missing_data
# Out:
#                  Column  Missing values count
# 0                    ID                     0
# 1                   Age                     0
# 2                Gender                     0
# 3             Height_cm                     0
# 4             Weight_kg                     0
# 5                   BMI                     0
# 6                Smoker                     0
# 7         Exercise_Freq                  1879
# 8          Diet_Quality                     0
# 9   Alcohol_Consumption                  1892
# 10      Chronic_Disease                     0
# 11         Stress_Level                     0
# 12          Sleep_Hours                     0

# %%
dataset['Exercise_Freq'].mode()[0]
# Out:
# 'Daily'

# %%
dataset['Alcohol_Consumption'].mode()[0]
# Out:
# 'Low'

# %%
dataset['Exercise_Freq'].fillna(dataset['Exercise_Freq'].mode()[0])
# Out:
# 0                Daily
# 1       1-2 times/week
# 2                Daily
# 3       3-5 times/week
# 4       3-5 times/week
#              ...
# 7495    1-2 times/week
# 7496    3-5 times/week
# 7497    3-5 times/week
# 7498    1-2 times/week
# 7499             Daily
# Name: Exercise_Freq, Length: 7500, dtype: object

# %%
dataset['Exercise_Freq'] = dataset['Exercise_Freq'].fillna(dataset['Exercise_Freq'].mode()[0])

# %%
dataset
# Out:
#         ID  Age  Gender  Height_cm  Weight_kg   BMI Smoker   Exercise_Freq  \
# 0        1   56   Other      177.6       37.3  11.8    Yes           Daily
# 1        2   69   Other      169.3       70.7  24.7     No  1-2 times/week
# 2        3   46  Female      159.1       69.0  27.3     No           Daily
# 3        4   32    Male      170.6       76.4  26.3     No  3-5 times/week
# 4        5   60    Male      158.4       60.4  24.1     No  3-5 times/week
# ...    ...  ...     ...        ...        ...   ...    ...             ...
# 7495  7496   55   Other      168.3       52.4  18.5    Yes  1-2 times/week
# 7496  7497   24    Male      179.1       58.8  18.3     No  3-5 times/week
# 7497  7498   61   Other      160.2       80.0  31.2     No  3-5 times/week
# 7498  7499   40  Female      172.6       66.1  22.2     No  1-2 times/week
# 7499  7500   58   Other      163.8       59.3  22.1     No           Daily
#
# ...

# %%
.
